# %%
import numpy as np
import matplotlib.pyplot as matplot

# %%
wageList = np.random.normal(4000, 500, 1000)

# %%
np.mean(wageList)
# Out:
# 3998.416615217192

# %%
matplot.hist(wageList, 50)
matplot.show()
